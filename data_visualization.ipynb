# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df=pd.read_csv("IRIS.csv")
print(df)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# x=np.array([5,7,8,9,0,12,23])

# y=np.array([6,22,21,14,10,13,25])

# %%
plt.scatter(df["sepal_length"],df["sepal_width"],c="purple")
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.show()

# %%
plt.scatter(df["petal_length"],df["petal_width"],c="purple")
plt.xlabel("petal_length")
plt.ylabel("petal_width")
plt.show()

# %%
x=[1,2,3]
y=[10,15,18]

# %%
plt.plot(x,y)
plt.title("Line graph")
plt.ylabel("Y axis")
plt.xlabel("X axis")
plt.show()

# %%
plt.plot(df["petal_length"],df["petal_width"],c="purple")
plt.show()

# %%
plt.plot(df["sepal_length"],df["sepal_width"],c="purple")
plt.show()

# %%
plt.bar(df["sepal_length"],df["sepal_width"])
plt.xlabel("sepal_lenght")
plt.xlabel("sepal_width")
plt.show()

# %%
x=[5,8,10]
y=[12,16,6]

x2=[6,9,11]
y2=[7,15,7]

# x3=[1,2,3]
# y3=[100,200,300]

# %%
plt.bar(x,y,color="y",align="center")
plt.bar(x2,y2,color="c",align="center")
# plt.bar(x3,y3,color="red",align="center")
plt.title("Information")
plt.xlabel("X axis")
plt.ylabel("Y axis")
# plt.zlabel("Z axis")
plt.show()
